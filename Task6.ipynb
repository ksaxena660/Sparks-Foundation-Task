# %% [markdown]
# ## Author : Kavya Saxena
#
# ## Task 6 : Prediction Using Decision Tree Algorithm
#
# ## GRIP @ The Sparks Foundation

# %% [markdown]
# ## Importing Relevant Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import Image

# %% [markdown]
# ## Loading the Dataset

# %%
data = pd.read_csv("Iris.csv")
x= data.iloc[:,1:-1].values
y = data.iloc[:,-1].values

# %% [markdown]
# ## Performing Explortory Data Analysis

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data.shape
# Out:
# (150, 6)

# %%
data.drop(["Id"],axis = 1 , inplace = True)
data
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
data.shape
# Out:
# (150, 5)

# %% [markdown]
# ## Data Visualization for Comparing Features

# %%
sns.pairplot(data)

# %%
# Scatter plot of data based on Sepal Length and Width features
sns.FacetGrid(data,hue='Species').map(plt.scatter,'SepalLengthCm','SepalWidthCm').add_legend()
plt.show()

# Scatter plot of data based on Petal Length and Width features
sns.FacetGrid(data,hue='Species').map(plt.scatter,'PetalLengthCm','PetalWidthCm').add_legend()
plt.show()

# %% [markdown]
# ## Splitting Data and Training Model Using Decision Tree Algorithm

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.25, random_state = 42)

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier()
clf.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# ## Predicting and Comparing Predicted Values to Actual Ones

# %%
y_pred = clf.predict(x_test)

# %%
df = pd.DataFrame({'Actual': y_test,'Predicted': y_pred})
df.head(10)
# Out:
#             Actual        Predicted
# 0  Iris-versicolor  Iris-versicolor
# 1      Iris-setosa      Iris-setosa
# 2   Iris-virginica   Iris-virginica
# 3  Iris-versicolor  Iris-versicolor
# 4  Iris-versicolor  Iris-versicolor
# 5      Iris-setosa      Iris-setosa
# 6  Iris-versicolor  Iris-versicolor
# 7   Iris-virginica   Iris-virginica
# 8  Iris-versicolor  Iris-versicolor
# 9  Iris-versicolor  Iris-versicolor

# %% [markdown]
# ## VIsualizing Predicted Data

# %%
from sklearn import tree

# %%
fn=['sepal length (cm)','sepal width (cm)','petal length (cm)','petal width (cm)']
cn=['setosa', 'versicolor', 'virginica']

# Setting dpi = 300 to make image clearer than default
fig, axes = plt.subplots(nrows = 1,ncols = 1,figsize = (4,4), dpi=300)

tree.plot_tree(clf,
           feature_names = fn, 
           class_names=cn,
           filled = True);

# %% [markdown]
# ## Checking the model for a random measurement of petal and sepal

# %% [markdown]
# We check our model for a random measurement of petals and sepals to check its accuracy.

# %%
clf.predict([[4.7,3.3,1.4,0.2]])
# Out:
# array(['Iris-setosa'], dtype=object)

# %% [markdown]
# Our model predicts it to be belonging to Iris-setosa specie.

# %% [markdown]
# ## Accuracy Of Model

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test,y_pred)
print("Accuracy Of Model is:",accuracy)
# Out:
# Accuracy Of Model is: 1.0

# %% [markdown]
# The accuracy comes out to be 1.0 or 100%
